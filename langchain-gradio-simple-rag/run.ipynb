# %%
# !virtualenv -p python3 venv
# !chmod +x venv/bin/activate
# !source ./venv/bin/activate

# %% [markdown]
# Install Python Librairie

# %%
# !pip uninstall -r requirements.txt -y
# !pip install -r requirements.txt

# %%
# !pip uninstall -y llama-index
# !pip uninstall -y langchain
# !pip uninstall -y gradio
# !pip uninstall -y python-dotenv
# !pip uninstall -y ipython
# Out:
# Found existing installation: llama-index 0.8.40
# Uninstalling llama-index-0.8.40:
#   Successfully uninstalled llama-index-0.8.40
# Found existing installation: langchain 0.0.309
# Uninstalling langchain-0.0.309:
#   Successfully uninstalled langchain-0.0.309
# Found existing installation: gradio 3.47.1
# Uninstalling gradio-3.47.1:
#   Successfully uninstalled gradio-3.47.1
# Found existing installation: python-dotenv 1.0.0
# Uninstalling python-dotenv-1.0.0:
#   Successfully uninstalled python-dotenv-1.0.0
# Found existing installation: ipython 8.16.1
# Uninstalling ipython-8.16.1:
#   Successfully uninstalled ipython-8.16.1

# %%
# !pip install llama-index
# !pip install langchain
# !pip install langchain==0.0.148
# !pip install gradio
# !pip install python-dotenv
# !pip install ipython
# Out:
# Collecting llama-index
#   Obtaining dependency information for llama-index from https://files.pythonhosted.org/packages/bc/01/0d3d74f373ac37eba8198aca82098437406b70be45990695c62f84156046/llama_index-0.8.40-py3-none-any.whl.metadata
#   Using cached llama_index-0.8.40-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: tiktoken in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from llama-index) (0.5.1)
# Requirement already satisfied: dataclasses-json in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from llama-index) (0.5.14)
# Collecting langchain>=0.0.303 (from llama-index)
#   Obtaining dependency information for langchain>=0.0.303 from https://files.pythonhosted.org/packages/7e/01/3236ef65067dee4172a7735fc34c43a80d61b3a8632fb5a8f0db37f345db/langchain-0.0.309-py3-none-any.whl.metadata
#   Using cached langchain-0.0.309-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: sqlalchemy>=2.0.15 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from llama-index) (2.0.21)
# Requirement already satisfied: numpy in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from llama-index) (1.26.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from llama-index) (8.2.3)
# Requirement already satisfied: openai>=0.26.4 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from llama-index) (0.28.1)
# Requirement already satisfied: pandas in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from llama-index) (2.1.1)
# Requirement already satisfied: urllib3<2 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from llama-index) (1.26.17)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from llama-index) (2023.9.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from llama-index) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from llama-index) (4.8.0)
# Requirement already satisfied: beautifulsoup4 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from llama-index) (4.12.2)
# Requirement already satisfied: nest-asyncio in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from llama-index) (1.5.8)
# Requirement already satisfied: nltk in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from llama-index) (3.8.1)
# Requirement already satisfied: PyYAML>=5.3 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain>=0.0.303->llama-index) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain>=0.0.303->llama-index) (3.8.5)
# Requirement already satisfied: anyio<4.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain>=0.0.303->llama-index) (3.7.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain>=0.0.303->llama-index) (4.0.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain>=0.0.303->llama-index) (1.33)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.40 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain>=0.0.303->llama-index) (0.0.43)
# Requirement already satisfied: pydantic<3,>=1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain>=0.0.303->llama-index) (1.10.13)
# Requirement already satisfied: requests<3,>=2 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain>=0.0.303->llama-index) (2.31.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from dataclasses-json->llama-index) (3.20.1)
# Requirement already satisfied: tqdm in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from openai>=0.26.4->llama-index) (4.66.1)
# Requirement already satisfied: greenlet!=0.4.17 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from sqlalchemy>=2.0.15->llama-index) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index) (1.0.0)
# Requirement already satisfied: soupsieve>1.2 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from beautifulsoup4->llama-index) (2.5)
# Requirement already satisfied: click in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from nltk->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from nltk->llama-index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from nltk->llama-index) (2023.10.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from pandas->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from pandas->llama-index) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from pandas->llama-index) (2023.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from anyio<4.0->langchain>=0.0.303->llama-index) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from anyio<4.0->langchain>=0.0.303->llama-index) (1.3.0)
# Requirement already satisfied: exceptiongroup in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from anyio<4.0->langchain>=0.0.303->llama-index) (1.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain>=0.0.303->llama-index) (2.4)
# Requirement already satisfied: packaging>=17.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index) (23.2)
# Requirement already satisfied: six>=1.5 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from requests<3,>=2->langchain>=0.0.303->llama-index) (2023.7.22)
# Using cached llama_index-0.8.40-py3-none-any.whl (866 kB)
# Using cached langchain-0.0.309-py3-none-any.whl (1.8 MB)
# Installing collected packages: langchain, llama-index
# Successfully installed langchain-0.0.309 llama-index-0.8.40
# Collecting langchain==0.0.148
#   Using cached langchain-0.0.148-py3-none-any.whl (636 kB)
# Requirement already satisfied: PyYAML>=5.4.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain==0.0.148) (6.0.1)
# Collecting SQLAlchemy<2,>=1 (from langchain==0.0.148)
#   Obtaining dependency information for SQLAlchemy<2,>=1 from https://files.pythonhosted.org/packages/77/68/4ce3f0677a4c5f51a91624a7c41921ea39aac1e39502d252ff339ec6cd3b/SQLAlchemy-1.4.49-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached SQLAlchemy-1.4.49-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain==0.0.148) (3.8.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain==0.0.148) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain==0.0.148) (0.5.14)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain==0.0.148) (2.8.7)
# Requirement already satisfied: numpy<2,>=1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain==0.0.148) (1.26.0)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain==0.0.148) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain==0.0.148) (1.10.13)
# Requirement already satisfied: requests<3,>=2 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain==0.0.148) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain==0.0.148) (8.2.3)
# Requirement already satisfied: tqdm>=4.48.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from langchain==0.0.148) (4.66.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.148) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.148) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.148) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.148) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.148) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.148) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.148) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.148) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from pydantic<2,>=1->langchain==0.0.148) (4.8.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.0.148) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.0.148) (1.26.17)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.0.148) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from SQLAlchemy<2,>=1->langchain==0.0.148) (3.0.0)
# Requirement already satisfied: packaging>=17.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.148) (23.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.148) (1.0.0)
# Using cached SQLAlchemy-1.4.49-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# Installing collected packages: SQLAlchemy, langchain
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.21
#     Uninstalling SQLAlchemy-2.0.21:
#       Successfully uninstalled SQLAlchemy-2.0.21
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.0.309
#     Uninstalling langchain-0.0.309:
#       Successfully uninstalled langchain-0.0.309
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index 0.8.40 requires langchain>=0.0.303, but you have langchain 0.0.148 which is incompatible.
# llama-index 0.8.40 requires sqlalchemy>=2.0.15, but you have sqlalchemy 1.4.49 which is incompatible.
# Successfully installed SQLAlchemy-1.4.49 langchain-0.0.148
# Collecting gradio
#   Obtaining dependency information for gradio from https://files.pythonhosted.org/packages/05/f2/360ca9546cffa45fee1df56864fdc2b6955de622e98435539490cd882a96/gradio-3.47.1-py3-none-any.whl.metadata
#   Using cached gradio-3.47.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (5.1.2)
# Requirement already satisfied: fastapi in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (0.103.2)
# Requirement already satisfied: ffmpy in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (0.3.1)
# Requirement already satisfied: gradio-client==0.6.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (0.6.0)
# Requirement already satisfied: httpx in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (0.25.0)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (0.17.3)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (6.1.0)
# Requirement already satisfied: jinja2<4.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (3.8.0)
# Requirement already satisfied: numpy~=1.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (1.26.0)
# Requirement already satisfied: orjson~=3.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (3.9.7)
# Requirement already satisfied: packaging in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (2.1.1)
# Requirement already satisfied: pillow<11.0,>=8.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (10.0.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (1.10.13)
# Requirement already satisfied: pydub in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: requests~=2.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (2.31.0)
# Requirement already satisfied: semantic-version~=2.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: typing-extensions~=4.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (4.8.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (0.23.2)
# Requirement already satisfied: websockets<12.0,>=10.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio) (11.0.3)
# Requirement already satisfied: fsspec in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from gradio-client==0.6.0->gradio) (2023.9.2)
# Requirement already satisfied: jsonschema>=3.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (4.19.1)
# Requirement already satisfied: toolz in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: filelock in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from huggingface-hub>=0.14.0->gradio) (3.12.4)
# Requirement already satisfied: tqdm>=4.42.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from huggingface-hub>=0.14.0->gradio) (4.66.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from requests~=2.0->gradio) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from requests~=2.0->gradio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from requests~=2.0->gradio) (1.26.17)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from requests~=2.0->gradio) (2023.7.22)
# Requirement already satisfied: click>=7.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from uvicorn>=0.14.0->gradio) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from fastapi->gradio) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: httpcore<0.19.0,>=0.18.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from httpx->gradio) (0.18.0)
# Requirement already satisfied: sniffio in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: exceptiongroup in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio) (1.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.10.4)
# Requirement already satisfied: six>=1.5 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Using cached gradio-3.47.1-py3-none-any.whl (20.3 MB)
# Installing collected packages: gradio
# Successfully installed gradio-3.47.1
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0
# Collecting ipython
#   Obtaining dependency information for ipython from https://files.pythonhosted.org/packages/ef/02/fc039fca3ec40a00f962eb6e9da45c507334b0650a3cb9facd38d234fb7a/ipython-8.16.1-py3-none-any.whl.metadata
#   Using cached ipython-8.16.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: backcall in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from ipython) (0.2.0)
# Requirement already satisfied: decorator in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from ipython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from ipython) (0.1.6)
# Requirement already satisfied: pickleshare in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from ipython) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from ipython) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from ipython) (2.16.1)
# Requirement already satisfied: stack-data in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from ipython) (5.11.2)
# Requirement already satisfied: exceptiongroup in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from ipython) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from ipython) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython) (0.2.8)
# Requirement already satisfied: executing>=1.2.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from stack-data->ipython) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from stack-data->ipython) (2.4.0)
# Requirement already satisfied: pure-eval in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)
# Using cached ipython-8.16.1-py3-none-any.whl (806 kB)
# Installing collected packages: ipython
# Successfully installed ipython-8.16.1

# %%
from langchain import OpenAI
from llama_index import SimpleDirectoryReader, LangchainEmbedding, GPTListIndex,readers, GPTSimpleVectorIndex, PromptHelper
# from llama_index import LLMPredictor, ServiceContext
import sys
#from google.colab import drive
import os
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /home/nkaurelien/Workspaces/Ysoconseils/playground/smartdatapay/langchain/run.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/nkaurelien/Workspaces/Ysoconseils/playground/smartdatapay/langchain/run.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from langchain import OpenAI
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/nkaurelien/Workspaces/Ysoconseils/playground/smartdatapay/langchain/run.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from llama_index import SimpleDirectoryReader, LangchainEmbedding, GPTListIndex,readers, GPTSimpleVectorIndex, PromptHelper
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/nkaurelien/Workspaces/Ysoconseils/playground/smartdatapay/langchain/run.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # from llama_index import LLMPredictor, ServiceContext
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/nkaurelien/Workspaces/Ysoconseils/playground/smartdatapay/langchain/run.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> import sys
#
# ImportError: cannot import name 'GPTSimpleVectorIndex' from 'llama_index' (/home/nkaurelien/Workspaces/Ysoconseils/playground/venv/lib/python3.10/site-packages/llama_index/__init__.py)

# %% [markdown]
# Create a .env file
#
# Example:
#
#
# OPENAI_API_KEY=sk-
# OPENAI_API_MODEL=gpt-3.5-turbo
# OPENAI_API_MODEL=text-davinci-003
# OPENAI_TEMPATURE=0.5
# KNOWLEDGE_BASE_PATH=/home/nkaurelien/Workspaces/ysoconseils/faqs_silae/public_html
# INPUT_INDEX=index.json

# %%
# os.environ["OPENAI_API_KEY"] = ''
from dotenv import load_dotenv

load_dotenv()

# %%
input_index = os.getenv('INPUT_INDEX', default='index.json')

# %%
def construct_index(directory_path):
  # set maximum input size
  max_input_size = 4096
  # set number of output tokens
  num_outputs = 256
  # set maximum chunk overlap
  max_chunk_overlap = 20
  # set chunk size limit
  chunk_size_limit = 600

  prompt_helper = PromptHelper(max_input_size, num_outputs, max_chunk_overlap, chunk_size_limit=chunk_size_limit)

  # define LLM
  llm_predictor = LLMPredictor(llm=OpenAI(temperature=0, model_name="text-davinci-002", max_tokens=num_outputs))
  
  documents = SimpleDirectoryReader(directory_path).load_data()
  
  service_context = ServiceContext.from_defaults(llm_predictor=llm_predictor)
  index = GPTSimpleVectorIndex.from_documents(documents, service_context=service_context)
  
  index.save_to_disk('index.json')
  
  return index

# %%
def ask_bot():
  index = GPTSimpleVectorIndex.load_from_disk(input_index)
  while True:
    query = input('What do you want to ask the bot?   \n')
    response = index.query(query, response_mode="compact")
    print ("\nBot says: \n\n" + response.response + "\n\n\n")

# %%
import gradio as gr

def chatbot(input_text):
    index = GPTSimpleVectorIndex.load_from_disk(input_index)
    # response = index.query(input_text, response_mode="compact")
    response = index.query(input_text)
    return response.response


def ask_bot_web_interface():

    iface = gr.Interface(fn=chatbot,
                     inputs=gr.components.Textbox(lines=4, label="Entrer votre texte"),
                     outputs="text",
                     title="Custom-trained AI Chatbot")
    iface.launch(share=True)

# %%
docs_path = os.getenv("KNOWLEDGE_BASE_PATH", default="/content/")
index = construct_index(docs_path)

# %%
ask_bot()

# %%
ask_bot_web_interface()
